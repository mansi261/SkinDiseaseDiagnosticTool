# %%
import pandas as pd

# %%
reduced_df = pd.read_csv('/Users/mansivyas/RA-MultiModel-ReducedSpecifciation/embeddings/skindisease_filtered_30.csv')

# %%
reduced_df_30 = reduced_df.head(100)

# %%
reduced_df_30.to_csv('skindisease_30.csv')

# %%
reduced_df_30.drop('Unnamed: 0',axis=1,inplace=True)
# Out:
# <ipython-input-8-b13ce64694fc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df_30.drop('Unnamed: 0',axis=1,inplace=True)

# %%
embeddigns_df = pd.read_csv('/Users/mansivyas/RA-MultiModel-ReducedSpecifciation/embeddings/embeddingsResnet30.csv')

# %%
embeddigns_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -2.307314 -0.851812 -1.337202 -1.462602 -1.443218 -2.149221  1.376229
# 1 -0.314007  0.123395  0.281063 -0.896183  0.587858  4.339354  5.176969
# 2 -2.121995 -0.818065 -0.530498  1.567056 -0.734692  5.135171  1.560257
# 3  0.182532  0.221331 -1.827309 -1.515033 -1.526238 -0.914144  1.215286
# 4 -0.193533 -0.454168  3.350655  1.076191 -0.996238  3.153634  3.104066
#
#           7         8         9  ...       991       992       993       994  \
# 0 -1.109207 -2.267908 -2.317307  ... -1.203554 -0.655277 -0.680223 -0.944335
# 1 -0.103512  0.491645 -2.356883  ... -0.825008 -1.386003  0.414105 -1.525284
# 2 -0.500374 -0.775628 -2.763740  ... -0.558277 -1.019685 -2.292870 -0.261777
# 3 -1.518711 -2.249483 -3.727486  ... -0.716953 -1.230591 -0.729046 -1.525985
# 4  1.741207  2.125491  0.338106  ... -2.519083 -0.677172 -0.482370 -1.146208
#
#         995       996       997       998       999  \
# 0  0.286784 -1.355640  1.292587  0.743471  3.313549
# 1  0.556033 -0.149585  0.715693  2.846572  1.279254
# 2  3.608913 -1.553597  1.632583 -0.130098  4.245875
# 3  2.211858 -0.592903  1.795957  2.821945  2.932290
# 4  1.277492  0.420475  0.360572  1.156173  0.356179
#
#                              label
# 0  drug induced pigmentary changes
# 1                  photodermatoses
# 2                   dermatofibroma
# 3                        psoriasis
# 4                        psoriasis
#
# [5 rows x 1001 columns]

# %%
column_to_move = 'label'

# Move the column
text_generartion_model_df = embeddigns_df[[column_to_move] + [col for col in embeddigns_df.columns if col != column_to_move]]

print(text_generartion_model_df)
# Out:
#                               label         0         1         2         3  \
# 0   drug induced pigmentary changes -2.307314 -0.851812 -1.337202 -1.462602
# 1                   photodermatoses -0.314007  0.123395  0.281063 -0.896183
# 2                    dermatofibroma -2.121995 -0.818065 -0.530498  1.567056
# 3                         psoriasis  0.182532  0.221331 -1.827309 -1.515033
# 4                         psoriasis -0.193533 -0.454168  3.350655  1.076191
# ..                              ...       ...       ...       ...       ...
# 95               pustular psoriasis  0.472551  0.698069  1.380612  2.021776
# 96                          scabies -1.336745 -0.106227 -1.016793  0.123096
# 97             basal cell carcinoma -2.306724  1.136877  5.592240  2.392494
# 98              ichthyosis vulgaris  0.236575  0.046470 -0.108082  0.228528
# 99                     lyme disease -2.784964  0.357200 -0.888504  0.685049
#
#            4         5         6         7         8  ...       990       991  \
# 0  -1.443218 -2.149221  1.376229 -1.109207 -2.267908  ...  1.395118 -1.203554
# 1   0.587858  4.339354  5.176969 -0.103512  0.491645  ...  0.287712 -0.825008
# 2  -0.734692  5.135171  1.560257 -0.500374 -0.775628  ...  1.594862 -0.558277
# 3  -1.526238 -0.914144  1.215286 -1.518711 -2.249483  ...  1.897278 -0.716953
# 4  -0.996238  3.153634  3.104066  1.741207  2.125491  ... -1.893696 -2.519083
# ..       ...       ...       ...       ...       ...  ...       ...       ...
# 95  0.814094  5.342254  3.647784  0.067781 -0.287122  ...  3.600850  4.072862
# 96  1.338972  4.603528  2.279249  0.265589  1.676780  ...  3.210197  3.680132
# 97  1.005949  4.030040  2.869393  2.329410  1.633372  ...  1.546694  0.422893
# 98 -0.596512 -0.681433  0.028748 -0.073407 -1.516664  ...  2.983797 -0.616998
# 99 -0.028520  1.616779  1.274199  0.141322 -0.384652  ...  1.818650  0.585721
#
#          992       993       994       995       996       997       998  \
# 0  -0.655277 -0.680223 -0.944335  0.286784 -1.355640  1.292587  0.743471
# 1  -1.386003  0.414105 -1.525284  0.556033 -0.149585  0.715693  2.846572
# 2  -1.019685 -2.292870 -0.261777  3.608913 -1.553597  1.632583 -0.130098
# 3  -1.230591 -0.729046 -1.525985  2.211858 -0.592903  1.795957  2.821945
# 4  -0.677172 -0.482370 -1.146208  1.277492  0.420475  0.360572  1.156173
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  4.072119  2.668978  5.782602  2.844317  3.343252  9.158352  1.843606
# 96  1.227887  0.562255  1.321697  0.038884  1.471093  4.163206  0.981207
# 97  2.438750  2.677823  5.409257  2.016215  0.028857  3.850727  1.844338
# 98 -0.484857 -0.693068 -0.413167  0.125163  0.154199  2.858792  0.721182
# 99 -0.214010 -0.747003  0.145001  0.267633 -1.444907  3.271638 -0.276436
#
#          999
# 0   3.313549
# 1   1.279254
# 2   4.245875
# 3   2.932290
# 4   0.356179
# ..       ...
# 95  0.390317
# 96 -0.253940
# 97  0.538002
# 98  1.513816
# 99  1.651239
#
# [100 rows x 1001 columns]

# %%
text_generartion_model_df.to_csv('embbedings_Resnet_30.csv')
